# %% [markdown]
# # Importing Data

# %%
#importing frames
import pandas as pd
import numpy as np
import os

# %%
# importing dataframe
path = r'C:\Users\ProUser11\Desktop\DATA ANALYSIS\Tasks\Module 5\4.1\2020 Instacart Basket Analysis'

# %%
# Importing orders_products_merged
orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#creating subset
df = orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# define a function

def price_label(row):
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\ProUser11\AppData\Local\Temp\ipykernel_1276\1199080080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
# Using Loc() function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\ProUser11\AppData\Local\Temp\ipykernel_1276\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Unsing Loc() on entire dataframe

# %%
orders_products_merged.loc[orders_products_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
orders_products_merged.loc[(orders_products_merged['prices'] <= 15) & (orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
orders_products_merged.loc[orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Counts Function
orders_products_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21861558
# Low-range product     10130750
# High-range product      412551
# Name: price_range_loc, dtype: int64

# %%
orders_products_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# The busiest days are 0 and 1 or Sat and Sun. Slowest days are Tuesday 3 and Wednesday 4.

# %%
result = []

for value in orders_products_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
orders_products_merged['busiest_day'] = result

# %%
orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task

# %% [markdown]
# 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Creating Plural columns
days = []

for day in orders_products_merged['orders_day_of_week']:
  if day == 0 or day == 1:
    days.append('Busiest days')
  elif day == 4 or day == 3:
    days.append('Slowest days')
  else:
    days.append('Regular days')

# %%
days
# Out:
# ['Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Regular days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular days',
# ...

# %%
orders_products_merged['busiest_days'] = days

# %%
orders_products_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: busiest_days, dtype: int64

# %%
print(orders_products_merged[['orders_day_of_week', 'busiest_days']].head(10))
# Out:
#    orders_day_of_week  busiest_days
# 0                   2  Regular days
# 1                   3  Slowest days
# 2                   3  Slowest days
# 3                   4  Slowest days
# 4                   4  Slowest days
# 5                   2  Regular days
# 6                   1  Busiest days
# 7                   1  Busiest days
# 8                   1  Busiest days
# 9                   4  Slowest days

# %%
print('Frequency hours_of_the_day:\n',orders_products_merged['order_hour_of_day'].value_counts())
# Out:
# Frequency hours_of_the_day:
#  10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# most frequent hour of the day is 10AM.

# %% [markdown]
# 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %% [markdown]
# Splitting the hours into groups: Most: (10, 11, 14, 15, 13, 12, 16, 9) Average: (17, 8, 18, 19, 20, 7, 21, 22)
# Least: (23, 6, 0, 1, 5, 2, 4, 3)

# %%
hours = []

for hour in orders_products_merged['order_hour_of_day']:
  if hour in [10, 11, 14, 15, 13, 12, 16, 9]:
    hours.append('Most orders')
  elif hour in [17, 8, 18, 19, 20, 7, 21, 22]:
    hours.append('Least orders')
  else:
    hours.append('Average orders')

# %%
# creating busiest_period_of_day column
orders_products_merged['busiest_period_of_day'] = hours

# %%
# Checking head
orders_products_merged[['order_hour_of_day', 'busiest_period_of_day']].head(10)
# Out:
#    order_hour_of_day busiest_period_of_day
# 0                  8          Least orders
# 1                  7          Least orders
# 2                 12           Most orders
# 3                  7          Least orders
# 4                 15           Most orders
# 5                  7          Least orders
# 6                  9           Most orders
# 7                 14           Most orders
# 8                 16           Most orders
# 9                  8          Least orders

# %% [markdown]
# 5. Print the frequency for this new column.

# %%
print(orders_products_merged['busiest_period_of_day'].value_counts())
# Out:
# Most orders       21118071
# Least orders       9997651
# Average orders     1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# 7. Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
orders_products_merged.to_pickle(r'C:\Users\ProUser11\Desktop\DATA ANALYSIS\Tasks\Module 5\4.1\2020 Instacart Basket Analysis\02 Data\Prepared Data\orders_products_merged_2.pkl')
